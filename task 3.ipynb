# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return si
def compound_interest(p,r,t):
    ci=  p * (1 + r /100) ** t
    return ci
n=int(input("enter the number of customers:"))
for i in  range(n):
    print(" \n number of customers",i+1)
    p=int(input("enter the pricipal:"))
    r=int(input("enter the rate :"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers: 3
#
#  number of customers 1
# enter the pricipal: 7565
# enter the rate : 4
# enter the time: 7
# simple_interest 2118.2
# compound_interest 9955.023909919131
#
#  number of customers 2
# enter the pricipal: 35332
# enter the rate : 7
# enter the time: 3
# simple_interest 7419.72
# compound_interest 43283.219276
#
#  number of customers 3
# enter the pricipal: 89i75
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 10
#       8 for i in  range(n):
#       9     print(" \n number of customers",i+1)
# ---> 10     p=int(input("enter the pricipal:"))
#      11     r=int(input("enter the rate :"))
#      12     t=int(input("enter the time:"))
#
# ValueError: invalid literal for int() with base 10: '89i75'
