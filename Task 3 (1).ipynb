# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return si
def compound_interest(p,r,t):
    ci=  p * (1 + r /100) ** t
    return ci
n=int(input("enter the number of customers:"))
for i in  range(n):
    print(" \n number of customers",i+1)
    p=int(input("enter the principal:"))
    r=int(input("enter the rate :"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers: 3
#
#  number of customers 1
# enter the principal: 6952
# enter the rate : 456
# enter the time: 2
# simple_interest 63402.24
# compound_interest 214911.34719999996
#
#  number of customers 2
# enter the principal: 3248
# enter the rate : 385
# enter the time: 3
# simple_interest 37514.4
# compound_interest 370545.2379999999
#
#  number of customers 3
# enter the principal: 8462
# enter the rate : 264
# enter the time: 1
# simple_interest 22339.68
# compound_interest 30801.68
