# %%
customer={"name": "Amit",
          "balance": 5000}
if customer ["balance"] > 2000:
  print("Good balance")
else:
  print("Low balance")
# Out:
# Good balance

# %%
account=("Priya", "Savings")
if account[1]=="Savings":
  print("Savings Account")
# Out:
# Savings Account

# %%
customers = ["navya","kawya","divya"]
for name in customers:
  print(name)
# Out:
# navya
# kawya
# divya

# %%
transactions=[600,-300,2000,-800]
for amount in transactions:
  if amount > 0:
    print("Credit")
  else:
    print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
amounts=[2200, 35000, 400, 6900, 5000]
for amount in amounts:
  if amount >5000:
    print("Large")
  else:
    print("Small")
# Out:
# Small
# Large
# Small
# Large
# Small

# %%
balance=10000
amount=float(input("Enter debit amount"))
if amount <=balance:
  print("Debit successful")
else:
  print("Insufficient balance")
# Out:
# Enter debit amount 2300
# Debit successful

# %%
transactions=[("Credit", 1000),
                ("Debit", 500)]
for t_type, amount in transactions:
  if t_type=="Credit":
    print("Added")
  elif t_type=="Debit":
    print("Deducted")
# Out:
# Added
# Deducted
